# %% [markdown]
# # IMPORTING THE LIBRARIES

# %%
import os
import pandas as pd
import pickle
import numpy as np
import seaborn as sns
import secrets
import cv2
from PIL import Image
from PIL import ImageFile
from sklearn.datasets import load_files

import matplotlib.pyplot as plt
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dropout, Flatten, Dense
from keras.models import Sequential

from keras.callbacks import ModelCheckpoint
from keras.utils import to_categorical
from sklearn.metrics import confusion_matrix
from keras.preprocessing import image 
import keras
from tqdm import tqdm
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import seaborn as sns
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score

# %% [markdown]
# # Defining the train,test and model directories

# %%
print(os.getcwd())
TEST_DIR = os.path.join(os.getcwd(),"imgs","test")
TRAIN_DIR = os.path.join(os.getcwd(),"imgs","train")
MODEL_PATH = os.path.join(os.getcwd(),"model","self_trained")
PICKLE_DIR = os.path.join(os.getcwd(),"pickle_files")
CSV_DIR = os.path.join(os.getcwd(),"csv_files")
# Out:
# C:\Users\bhavy\Downloads\Distracted-Driver-Detection-master\Distracted-Driver-Detection-master\Training Notebooks

# %%
if not os.path.exists(TEST_DIR):
    print("Testing data does not exists")
if not os.path.exists(TRAIN_DIR):
    print("Training data does not exists")
if not os.path.exists(MODEL_PATH):
    print("Model path does not exists")
    os.makedirs(MODEL_PATH)
    print("Model path created")
if not os.path.exists(PICKLE_DIR):
    os.makedirs(PICKLE_DIR)
if not os.path.exists(CSV_DIR):
    os.makedirs(CSV_DIR)

# %%
gen_per_image = 1
gen_per_class = 200
rotation_range = 5
width_shift_range = 0.02
height_shift_range = 0.02
shear_range = 0.01
zoom_range = 0.05
horizontal_flip = False
fill_mode = "nearest"

# %%
height_shift_range = 0.02
shear_range = 0.01
zoom_range = 0.05
horizontal_flip = False
fill_mode = "nearest"

def increase_brightness(img, value):
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    h, s, v = cv2.split(hsv)

    lim = 255 - value
    v[v > lim] = 255
    v[v <= lim] += value

    final_hsv = cv2.merge((h, s, v))
    img = cv2.cvtColor(final_hsv, cv2.COLOR_HSV2BGR)
    return img

def change_contrast(img, level):
    img = Image.fromarray(img.astype('uint8'))
    factor = (259 * (level + 255)) / (255 * (259 - level))
    def contrast(c):
        return 128 + factor * (c - 128)
    return np.array(img.point(contrast))

def pad_img(img):
    h, w = img.shape[:2]
    new_h = int((5 + secrets.randbelow(16)) * h / 100) + h
    new_w = int((5 + secrets.randbelow(16)) * w / 100) + w

    full_sheet = np.ones((new_h, new_w, 3)) * 255

    p_X = secrets.randbelow(new_h - img.shape[0])
    p_Y = secrets.randbelow(new_w - img.shape[1])

    full_sheet[p_X : p_X + img.shape[0], p_Y : p_Y + img.shape[1]] = img

    full_sheet = cv2.resize(full_sheet, (w, h), interpolation = cv2.INTER_AREA)

    return full_sheet.astype(np.uint8)

def preprocess_img(img):
    img = np.array(img)

    x = secrets.randbelow(2)

    if x == 0:
        # img = pad_img(img)
        img = increase_brightness(img, secrets.randbelow(26))
        img = change_contrast(img, secrets.randbelow(51))
    else:
        # img = pad_img(img)
        img = change_contrast(img, secrets.randbelow(51))
        img = increase_brightness(img, secrets.randbelow(26))

    return img

# %%
BATCH_SIZE = 128
IMAGE_SIZE = 224
NUM_EPOCH = 25

# %%
datagen = ImageDataGenerator(
        rotation_range = rotation_range,
        width_shift_range = width_shift_range,
        height_shift_range = height_shift_range,
        shear_range = shear_range,
        zoom_range = zoom_range,
        horizontal_flip = horizontal_flip,
        fill_mode = fill_mode,
        validation_split = 0.2,
        preprocessing_function = preprocess_img)


train_data = datagen.flow_from_directory(TRAIN_DIR,
                                        target_size=(IMAGE_SIZE,IMAGE_SIZE),
                                        batch_size=BATCH_SIZE,
                                        subset='training',shuffle=False)

valid_data = datagen.flow_from_directory(TRAIN_DIR,
                                        target_size=(IMAGE_SIZE,IMAGE_SIZE),
                                        batch_size=BATCH_SIZE,
                                        subset='validation',shuffle=False)
# Out:
# Found 17943 images belonging to 10 classes.
# Found 4481 images belonging to 10 classes.

# %% [markdown]
# # Defining the Model

# %%
model = Sequential()

model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu', input_shape=(IMAGE_SIZE,IMAGE_SIZE,3), kernel_initializer='glorot_normal'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=128, kernel_size=2, padding='same', activation='relu', kernel_initializer='glorot_normal'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=256, kernel_size=2, padding='same', activation='relu', kernel_initializer='glorot_normal'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=512, kernel_size=2, padding='same', activation='relu', kernel_initializer='glorot_normal'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(500, activation='relu', kernel_initializer='glorot_normal'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax', kernel_initializer='glorot_normal'))


model.summary()
# Out:
# C:\Users\bhavy\anaconda3\lib\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 224, 224, 64)        │             832 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 112, 112, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 112, 112, 128)       │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 56, 56, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 56, 56, 256)         │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 28, 28, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 28, 28, 512)         │         524,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 100352)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 500)                 │      50,176,500 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 500)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           5,010 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 50,871,366 (194.06 MB)
#  Trainable params: 50,871,366 (194.06 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
filepath = os.path.join(MODEL_PATH, "distracted-{epoch:02d}-{val_accuracy:.2f}.keras")
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

# %%
model_history = model.fit(train_data,validation_data = valid_data,epochs=NUM_EPOCH,shuffle=True,callbacks=callbacks_list)
# Out:
# Epoch 1/25
# C:\Users\bhavy\anaconda3\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.1247 - loss: 1538.4298
# Epoch 1: val_accuracy improved from -inf to 0.21714, saving model to C:\Users\bhavy\Downloads\Distracted-Driver-Detection-master\Distracted-Driver-Detection-master\Training Notebooks\model\self_trained\distracted-01-0.22.keras
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 820s 6s/step - accuracy: 0.1244 - loss: 1530.0389 - val_accuracy: 0.2171 - val_loss: 2.2430
# Epoch 2/25
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.1472 - loss: 9.9378
# Epoch 2: val_accuracy did not improve from 0.21714
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 689s 5s/step - accuracy: 0.1473 - loss: 9.9138 - val_accuracy: 0.1522 - val_loss: 2.3274
# Epoch 3/25
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.2020 - loss: 2.5367
# Epoch 3: val_accuracy improved from 0.21714 to 0.42513, saving model to C:\Users\bhavy\Downloads\Distracted-Driver-Detection-master\Distracted-Driver-Detection-master\Training Notebooks\model\self_trained\distracted-03-0.43.keras
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 660s 5s/step - accuracy: 0.2022 - loss: 2.5356 - val_accuracy: 0.4251 - val_loss: 1.6085
# Epoch 4/25
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.3411 - loss: 2.5416
# Epoch 4: val_accuracy did not improve from 0.42513
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 753s 5s/step - accuracy: 0.3415 - loss: 2.5397 - val_accuracy: 0.1076 - val_loss: 12.4686
# Epoch 5/25
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.4645 - loss: 2.8168
# Epoch 5: val_accuracy improved from 0.42513 to 0.68087, saving model to C:\Users\bhavy\Downloads\Distracted-Driver-Detection-master\Distracted-Driver-Detection-master\Training Notebooks\model\self_trained\distracted-05-0.68.keras
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 856s 6s/step - accuracy: 0.4649 - loss: 2.8091 - val_accuracy: 0.6809 - val_loss: 0.9325
# Epoch 6/25
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6042 - loss: 1.3496
# Epoch 6: val_accuracy improved from 0.68087 to 0.84445, saving model to C:\Users\bhavy\Downloads\Distracted-Driver-Detection-master\Distracted-Driver-Detection-master\Training Notebooks\model\self_trained\distracted-06-0.84.keras
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 843s 6s/step - accuracy: 0.6046 - loss: 1.3481 - val_accuracy: 0.8445 - val_loss: 0.5203
# Epoch 7/25
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.7308 - loss: 0.8172
# Epoch 7: val_accuracy improved from 0.84445 to 0.90761, saving model to C:\Users\bhavy\Downloads\Distracted-Driver-Detection-master\Distracted-Driver-Detection-master\Training Notebooks\model\self_trained\distracted-07-0.91.keras
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 849s 6s/step - accuracy: 0.7310 - loss: 0.8168 - val_accuracy: 0.9076 - val_loss: 0.3023
# Epoch 8/25
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.8192 - loss: 0.5837
# Epoch 8: val_accuracy did not improve from 0.90761
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 839s 6s/step - accuracy: 0.8193 - loss: 0.5835 - val_accuracy: 0.8565 - val_loss: 0.3597
# Epoch 9/25
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.8610 - loss: 0.4452
# Epoch 9: val_accuracy improved from 0.90761 to 0.94689, saving model to C:\Users\bhavy\Downloads\Distracted-Driver-Detection-master\Distracted-Driver-Detection-master\Training Notebooks\model\self_trained\distracted-09-0.95.keras
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 854s 6s/step - accuracy: 0.8611 - loss: 0.4452 - val_accuracy: 0.9469 - val_loss: 0.1647
# Epoch 10/25
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 24s/step - accuracy: 0.8935 - loss: 0.3581
# Epoch 10: val_accuracy improved from 0.94689 to 0.94733, saving model to C:\Users\bhavy\Downloads\Distracted-Driver-Detection-master\Distracted-Driver-Detection-master\Training Notebooks\model\self_trained\distracted-10-0.95.keras
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 3534s 25s/step - accuracy: 0.8936 - loss: 0.3579 - val_accuracy: 0.9473 - val_loss: 0.1633
# Epoch 11/25
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9148 - loss: 0.2772
# Epoch 11: val_accuracy improved from 0.94733 to 0.96474, saving model to C:\Users\bhavy\Downloads\Distracted-Driver-Detection-master\Distracted-Driver-Detection-master\Training Notebooks\model\self_trained\distracted-11-0.96.keras
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 703s 5s/step - accuracy: 0.9148 - loss: 0.2772 - val_accuracy: 0.9647 - val_loss: 0.1346
# Epoch 12/25
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9214 - loss: 0.2503
# Epoch 12: val_accuracy did not improve from 0.96474
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 698s 5s/step - accuracy: 0.9215 - loss: 0.2501 - val_accuracy: 0.9478 - val_loss: 0.1722
# Epoch 13/25
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9421 - loss: 0.2098
# Epoch 13: val_accuracy improved from 0.96474 to 0.98237, saving model to C:\Users\bhavy\Downloads\Distracted-Driver-Detection-master\Distracted-Driver-Detection-master\Training Notebooks\model\self_trained\distracted-13-0.98.keras
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 690s 5s/step - accuracy: 0.9420 - loss: 0.2099 - val_accuracy: 0.9824 - val_loss: 0.0671
# Epoch 14/25
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9447 - loss: 0.1882
# Epoch 14: val_accuracy did not improve from 0.98237
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 694s 5s/step - accuracy: 0.9447 - loss: 0.1882 - val_accuracy: 0.9732 - val_loss: 0.0974
# Epoch 15/25
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9437 - loss: 0.1983
# Epoch 15: val_accuracy improved from 0.98237 to 0.98527, saving model to C:\Users\bhavy\Downloads\Distracted-Driver-Detection-master\Distracted-Driver-Detection-master\Training Notebooks\model\self_trained\distracted-15-0.99.keras
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 694s 5s/step - accuracy: 0.9437 - loss: 0.1982 - val_accuracy: 0.9853 - val_loss: 0.0484
# Epoch 16/25
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9505 - loss: 0.1767
# Epoch 16: val_accuracy improved from 0.98527 to 0.98661, saving model to C:\Users\bhavy\Downloads\Distracted-Driver-Detection-master\Distracted-Driver-Detection-master\Training Notebooks\model\self_trained\distracted-16-0.99.keras
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 723s 5s/step - accuracy: 0.9505 - loss: 0.1767 - val_accuracy: 0.9866 - val_loss: 0.0490
# Epoch 17/25
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9533 - loss: 0.1767
# Epoch 17: val_accuracy did not improve from 0.98661
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 705s 5s/step - accuracy: 0.9532 - loss: 0.1768 - val_accuracy: 0.9864 - val_loss: 0.0530
# Epoch 18/25
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9596 - loss: 0.1435
# Epoch 18: val_accuracy did not improve from 0.98661
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 690s 5s/step - accuracy: 0.9596 - loss: 0.1435 - val_accuracy: 0.9815 - val_loss: 0.0747
# Epoch 19/25
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9504 - loss: 0.1798
# Epoch 19: val_accuracy improved from 0.98661 to 0.98840, saving model to C:\Users\bhavy\Downloads\Distracted-Driver-Detection-master\Distracted-Driver-Detection-master\Training Notebooks\model\self_trained\distracted-19-0.99.keras
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 676s 5s/step - accuracy: 0.9505 - loss: 0.1796 - val_accuracy: 0.9884 - val_loss: 0.0462
# Epoch 20/25
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9651 - loss: 0.1418
# Epoch 20: val_accuracy did not improve from 0.98840
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 668s 5s/step - accuracy: 0.9651 - loss: 0.1419 - val_accuracy: 0.9875 - val_loss: 0.0518
# Epoch 21/25
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9682 - loss: 0.1154
# Epoch 21: val_accuracy did not improve from 0.98840
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 667s 5s/step - accuracy: 0.9682 - loss: 0.1154 - val_accuracy: 0.9842 - val_loss: 0.0533
# Epoch 22/25
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9679 - loss: 0.1132
# Epoch 22: val_accuracy did not improve from 0.98840
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 733s 5s/step - accuracy: 0.9679 - loss: 0.1133 - val_accuracy: 0.9857 - val_loss: 0.0445
# Epoch 23/25
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9699 - loss: 0.1151
# Epoch 23: val_accuracy did not improve from 0.98840
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 786s 5s/step - accuracy: 0.9699 - loss: 0.1152 - val_accuracy: 0.9784 - val_loss: 0.0880
# Epoch 24/25
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9665 - loss: 0.1220
# Epoch 24: val_accuracy did not improve from 0.98840
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 752s 5s/step - accuracy: 0.9666 - loss: 0.1220 - val_accuracy: 0.9884 - val_loss: 0.0381
# Epoch 25/25
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.9691 - loss: 0.1266
# Epoch 25: val_accuracy did not improve from 0.98840
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 914s 6s/step - accuracy: 0.9691 - loss: 0.1267 - val_accuracy: 0.9884 - val_loss: 0.0488

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 12))
ax1.plot(model_history.history['loss'], color='b', label="Training loss")
ax1.plot(model_history.history['val_loss'], color='r', label="validation loss")
ax1.set_xticks(np.arange(1, 25, 1))
ax1.set_yticks(np.arange(0, 1, 0.1))

ax2.plot(model_history.history['accuracy'], color='b', label="Training accuracy")
ax2.plot(model_history.history['val_accuracy'], color='r',label="Validation accuracy")
ax2.set_xticks(np.arange(1, 25, 1))

legend = plt.legend(loc='best', shadow=True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Model Analysis
#
# Finding the Confusion matrix,Precision,Recall and F1 score to analyse the model thus created

# %%
def print_confusion_matrix(confusion_matrix, class_names, figsize = (10,7), fontsize=14):
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names, columns=class_names, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    fig.savefig(os.path.join(MODEL_PATH,"confusion_matrix.png"))
    return fig

# %%
def print_heatmap(n_labels, n_predictions, class_names):
    labels = n_labels
    predictions = n_predictions 


    matrix = confusion_matrix(labels,predictions.argmax(axis=1))
    row_sum = np.sum(matrix, axis = 1)
    w, h = matrix.shape

    c_m = np.zeros((w, h))

    for i in range(h):
        c_m[i] = matrix[i] * 100 / row_sum[i]

    c = c_m.astype(dtype = np.uint8)

    
    heatmap = print_confusion_matrix(c, class_names, figsize=(18,10), fontsize=20)

# %%
ypred = model.predict(valid_data)

valid_list = valid_data.classes.tolist()

ypred_class = np.argmax(ypred,axis=1)
ytest = valid_list
# Out:
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 94s 3s/step

# %%
class_names = list()
for name,idx in valid_data.class_indices.items():
    class_names.append(name)
print(class_names)
# Out:
# ['c0', 'c1', 'c2', 'c3', 'c4', 'c5', 'c6', 'c7', 'c8', 'c9']

# %%
print_heatmap(ytest,ypred,class_names)

# %% [markdown]
# ## Precision Recall F1 Score

# %%
accuracy = accuracy_score(ytest,ypred_class)
print('Accuracy: %f' % accuracy)

precision = precision_score(ytest, ypred_class,average='weighted')
print('Precision: %f' % precision)

recall = recall_score(ytest,ypred_class,average='weighted')
print('Recall: %f' % recall)

f1 = f1_score(ytest,ypred_class,average='weighted')
print('F1 score: %f' % f1)
# Out:
# Accuracy: 0.987503
# Precision: 0.987596
# Recall: 0.987503
# F1 score: 0.987465

# %%
model.evaluate(valid_data)
# Out:
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 93s 3s/step - accuracy: 0.9890 - loss: 0.0501
# [0.053605109453201294, 0.9881722927093506]
